# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
filepath1 = r'/home/liusheng/worksapce2024/github/Real-ESRGAN/datasets/CBCT/cbct/2PA001_5.npy'
filepath2 = r'/home/liusheng/worksapce2024/github/Real-ESRGAN/datasets/CBCT/ct/2PA001_5.npy'

data1 = np.load(filepath1)
print(data1.shape)

data2 = np.load(filepath2)
print(data2.shape)
# Out:
# (480, 480)
# (480, 480)

# %%
plt.subplot(1,2,1)
plt.imshow(data1)
plt.title('CBCT')
plt.colorbar()
plt.subplot(1,2,2)
plt.imshow(data2)
plt.title('CT')
plt.colorbar()
# Out:
# Text(0.5, 1.0, 'CT')

# %%
CUDA_VISIBLE_DEVICES=6 python /home/liusheng/worksapce2024/github/Real-ESRGAN/inference_realesrgan_cbct.py --model_name RealESRGAN_x1plus_cbct --outscale 1 --model_path /home/liusheng/worksapce2024/github/Real-ESRGAN/experiments/train_RealESRGANx1plus_50K_gray_from_zero_cbct/models/net_g_20000.pth --input /home/liusheng/worksapce2024/github/Real-ESRGAN/datasets/CBCT/test_set/cbct_input --output /home/liusheng/worksapce2024/github/Real-ESRGAN/datasets/CBCT/test_set/gan_ct_out/epoch20000

# %%
CUDA_VISIBLE_DEVICES=6 python /home/liusheng/worksapce2024/github/Real-ESRGAN/inference_realesrgan_cbct.py --model_name RealESRGAN_x1plus_cbct --outscale 1 --model_path /home/liusheng/worksapce2024/github/Real-ESRGAN/experiments/train_RealESRNetx2plus_7k_cbct/models/net_g_50000.pth --input /home/liusheng/worksapce2024/github/Real-ESRGAN/datasets/CBCT/test_set/cbct_input --output /home/liusheng/worksapce2024/github/Real-ESRGAN/datasets/CBCT/test_set/gan_ct_out/test2

# %%
CUDA_VISIBLE_DEVICES=6 python /home/liusheng/worksapce2024/github/Real-ESRGAN/inference_realesrgan_cbct.py --model_name RealESRGAN_x1plus_cbct --outscale 1 --model_path /home/liusheng/worksapce2024/github/Real-ESRGAN/experiments/train_RealESRGANx1plus_50K_gray_from_zero_cbct2/models/net_g_500.pth --input /home/liusheng/worksapce2024/github/Real-ESRGAN/datasets/CBCT/test_set/cbct_input --output /home/liusheng/worksapce2024/github/Real-ESRGAN/datasets/CBCT/test_set/gan_no_pl_ct_out/test

# %%
/home/liusheng/worksapce2024/github/Real-ESRGAN/experiments/train_RealESRGANx1plus_50K_gray_from_zero_cbct2/models/net_g_500.pth
